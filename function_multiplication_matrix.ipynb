# %%
import pandas as pd
import tensorflow as tf
import numpy as np
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
data = pd.read_csv('tripad_data.csv')

# %%
data_over = data.drop(data.columns[[0,2,4,11,12,13,14,15,16,17]], axis='columns')
#data_UPC = data_1.drop(data.columns[[1]],axis='columns')
#data_IPC = data_1.drop(data.columns[[3]],axis='columns')

data_over.to_csv('data_over.csv')

#data_IPC.to_csv('IPC.csv')
#data_UPC.to_csv('UPC.csv')

#data_IPC.head()
#data_UPC.head()

# %% [markdown]
# ## 5~54개 리뷰를 작성한 사람으로 데이터 전처리

# %%
def len_pre(data_over):
    data_count = data_over['Author'].value_counts()
    tmp = pd.DataFrame(data_count.index, columns=['Author'])
    tmp['count'] = data_count.values
    data_count = tmp


    np_data = np.array(data_count)
    np_data=np_data[np.where(np_data[:,1]>=10)]
    np_data=np_data[np.where(np_data[:,1]<=50)]

    np_data = np.delete(np_data,(1),axis=1)
    df1 = pd.DataFrame(columns=['name'])
    name = np_data.reshape(-1,)
    df1['name']= name
    data_over= data_over[data_over['Author'].isin(df1['name'])]
    data_over = data_over.reset_index(drop=True)
    
    return data_over

# %%
# Out:
# array([['Mike M', 50],
#        ['David C', 50],
#        ['NoneNamedYet', 49],
#        ...,
#        ['kguerra', 10],
#        ['FamilyTravellers2008', 10],
#        ['kirra99', 10]], dtype=object)

# %%
data_over= data_over[data_over['Author'].isin(df1['name'])]
data_over = data_over.reset_index(drop=True)
data_over.to_csv('over_pre.csv')

# %% [markdown]
# ## UPC 전처리

# %%
data_over.head()
# Out:
#    HotelInfo.HotelID       Author  Service  Cleanliness  Rooms  Value  \
# 0             241011  Elizabeth R        1            1      1      1
# 1             241011       John P        1            1      1      1
# 2             241011       Jeff C        5            5      4      5
# 3             241011     Joanne L        4            4      4      4
# 4            2515990   Davynessie        3            3      3      3
#
#    Sleep Quality  Location
# 0              0         1
# 1              0         2
# 2              0         5
# 3              0         0
# 4              0         4

# %%
data_UPC = data_over.drop(['HotelInfo.HotelID'],axis='columns')
data_UPC = data_UPC.drop_duplicates(["Author"])
data_UPC = data_UPC.reset_index(drop=True)
data_UPC.to_csv('UPC.csv')

# %%
data_UPC
# Out:
#             Author  Service  Cleanliness  Rooms  Value  Sleep Quality  \
# 0      Elizabeth R        1            1      1      1              0
# 1           John P        1            1      1      1              0
# 2           Jeff C        5            5      4      5              0
# 3         Joanne L        4            4      4      4              0
# 4       Davynessie        3            3      3      3              0
# ...            ...      ...          ...    ...    ...            ...
# 24079     baltohon        5            5      4      3              4
# 24080        fitzN        5            5      0      1              3
# 24081  Sylvie10013        2            3      2      2              0
# 24082         ESJT        4            4      4      4              4
# 24083     larad427        3            4      4      3              0
#
#        Location
# 0             1
# 1             2
# 2             5
# 3             0
# 4             4
# ...         ...
# ...

# %% [markdown]
# ## IPC 전처리

# %%
data_IPC = data_over.drop(['Author'],axis='columns')
data_IPC = data_IPC.drop_duplicates(["HotelInfo.HotelID"])
data_IPC = data_IPC.reset_index(drop=True)
data_IPC.to_csv('IPC.csv')

# %%
data_IPC.head()
# Out:
#    HotelInfo.HotelID  Service  Cleanliness  Rooms  Value  Sleep Quality  \
# 0             241011        1            1      1      1              0
# 1            2515990        3            3      3      3              0
# 2             555239        4            4      2      4              0
# 3             535838        3            3      3      3              3
# 4            2514378        4            4      4      5              4
#
#    Location
# 0         1
# 1         4
# 2         4
# 3         5
# 4         4

# %%
data_IPC
# Out:
#       HotelInfo.HotelID  Service  Cleanliness  Rooms  Value  Sleep Quality  \
# 0                241011        1            1      1      1              0
# 1               2515990        3            3      3      3              0
# 2                555239        4            4      2      4              0
# 3                535838        3            3      3      3              3
# 4               2514378        4            4      4      5              4
# ...                 ...      ...          ...    ...    ...            ...
# 6769             203133        5            5      0      5              5
# 6770            2514183        5            4      3      5              4
# 6771            2514479        3            3      2      4              3
# 6772             239472        5            5      5      5              0
# 6773              78587        5            4      4      4              3
#
#       Location
# 0            1
# 1            4
# 2            4
# ...

# %% [markdown]
# ## 행렬 곱 연산

# %%
def matrix_multiplication(IPC,UPC):
    #호텔, 저자 이름 추출
    hotel_name = data_IPC['HotelInfo.HotelID']
    test_IPC = data_IPC.drop(['HotelInfo.HotelID'],axis=1)

    Author_name = data_UPC['Author']
    test_UPC = data_UPC.drop(['Author'],axis=1)
    ##################################################################

    trans_UPC=np.transpose(test_UPC)

    predict_matrix = np.dot(test_IPC,trans_UPC)
    predict_matrix = pd.DataFrame(predict_matrix)

    predict_matrix.columns=Author_name
    predict_matrix.index = hotel_name
    
    return predict_matrix


predict_matrix = matrix_multiplication(data_IPC,data_UPC)

# %%
predict_matrix.to_csv('predict_matrix.csv')
